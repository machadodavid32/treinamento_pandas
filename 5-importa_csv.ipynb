# %%
import pandas as pd

# %%
df_produdos = pd.read_csv("dados/produtos.csv", delimiter=";")
df_produdos
# Out:
#    Unnamed: 0                       nome  id  preco
# 0           0  Smartphone Samsung Galaxy   0   2500
# 1           1     Notebook Dell Inspiron   1   4500
# 2           2          Tablet Apple Ipad   2   3000
# 3           3          Smartwatch Garmin   3   1200
# 4           4        Fone de Ouvido Sony   4    600

# %%
df_produdos.head(2) # mostra os dois primeiros
# Out:
#    Unnamed: 0                       nome  id  preco
# 0           0  Smartphone Samsung Galaxy   0   2500
# 1           1     Notebook Dell Inspiron   1   4500

# %%
df_produdos.tail(3) # mostra os 3 ultimos
# Out:
#    Unnamed: 0                 nome  id  preco
# 2           2    Tablet Apple Ipad   2   3000
# 3           3    Smartwatch Garmin   3   1200
# 4           4  Fone de Ouvido Sony   4    600

# %%
df_produdos.shape # Mostra o formado, no caso, 5 linhas e 4 colunas
# Out:
# (5, 4)

# %%
df_produdos.dtypes # Tipo de dados para cada coluna
# Out:
# Unnamed: 0     int64
# nome          object
# id             int64
# preco          int64
# dtype: object

# %%
df_produdos.sort_values(by='preco', ascending=False) # Ordena a coluna por alguma coluna, no caso, pela coluna preco do maior para o menor
# Out:
#    Unnamed: 0                       nome  id  preco
# 1           1     Notebook Dell Inspiron   1   4500
# 2           2          Tablet Apple Ipad   2   3000
# 0           0  Smartphone Samsung Galaxy   0   2500
# 3           3          Smartwatch Garmin   3   1200
# 4           4        Fone de Ouvido Sony   4    600

# %%
df_compras = pd.read_csv("dados/compras.csv", delimiter=";")
df_compras
# Out:
#                             data  id_compra            loja         vendedor  \
# 0     2023-12-19 19:29:20.923259          0   Florianópolis       Tiago Lima
# 1     2023-12-19 20:54:22.408124          1       São Paulo    Lucas Pereira
# 2     2023-12-19 21:41:26.807241          2    Porto Alegre    Mariana Gomes
# 3     2023-12-19 22:28:32.305525          3    Porto Alegre    Mariana Gomes
# 4     2023-12-19 23:14:29.902292          4       São Paulo     Ana Oliveira
# ...                          ...        ...             ...              ...
# 1995  2024-12-16 23:54:23.300770       1995   Florianópolis  Gabriela Santos
# 1996  2024-12-17 01:43:16.898312       1996  Rio de Janeiro      Pedro Souza
# 1997  2024-12-17 18:18:31.001283       1997  Rio de Janeiro  Juliana Almeida
# 1998  2024-12-17 19:58:25.448468       1998  Belo Horizonte   Fernanda Costa
# 1999  2024-12-18 01:36:30.425281       1999  Belo Horizonte   Fernanda Costa
#
# ...

# %%
df_compras['produto'].value_counts() # conta a quantidade de cada produto
# Out:
# produto
# Tablet Apple Ipad            406
# Notebook Dell Inspiron       405
# Smartphone Samsung Galaxy    401
# Fone de Ouvido Sony          398
# Smartwatch Garmin            390
# Name: count, dtype: int64
